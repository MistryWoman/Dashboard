# %%
import pandas as pd
import collections
import os

# %%
from gensim.models import Word2Vec
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],['this', 'is', 'the', 'second', 'sentence'],
['yet', 'another', 'sentence'],
['one', 'more', 'sentence'],
['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# summarize the loaded model
# print(model)
# summarize vocabulary
words = list(model.wv.vocab)
# print(words)
# access vector for one word
print(model['sentence'])
# save model
# model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
# print(new_model)
# Out:
# [-2.6673467e-03  7.9005229e-04 -1.5832403e-03 -4.4669937e-03
#  -1.7168296e-03 -4.4462527e-03  2.8164661e-03 -4.7084056e-03
#  -1.7046465e-03 -2.8942963e-03 -1.6999110e-03 -3.3925120e-03
#  -4.4337953e-03 -1.5665510e-03 -3.8156200e-03 -2.9390000e-03
#  -1.4237434e-03 -3.2325156e-03  1.0619400e-03 -3.1089727e-03
#  -2.8779591e-03  1.6807300e-03  3.1339296e-03 -4.8856819e-03
#   3.5231272e-03 -3.0391542e-03 -3.5587689e-03  3.3638943e-03
#   2.1763695e-03  6.9167413e-04 -4.2263884e-03  2.1153858e-03
#   3.1059445e-03 -2.8584394e-04 -4.6024313e-03 -3.9712908e-03
#   4.6284772e-03 -4.0360666e-03  3.4056078e-03  1.9468748e-03
#   2.7636625e-03 -4.4098524e-03 -3.7128734e-03  3.4890207e-03
#   2.8097848e-03  6.8385081e-05  7.8348361e-04  1.4187780e-03
#  -4.3011713e-03  1.7619880e-03  3.5129692e-03  1.1744904e-03
#  -3.6442361e-03 -3.6727189e-04 -1.2343770e-03 -3.8186305e-03
#  -3.6425006e-03 -2.8425788e-03 -3.5567887e-03 -1.1993085e-03
#   3.5672439e-03 -4.8331218e-03  2.5068142e-03  3.4056189e-03
#   8.2996377e-04  3.7161121e-03  2.8227386e-03  9.6967956e-04
#  -2.6695291e-03  1.9672571e-03  1.8171157e-03 -1.7440177e-03
#  -1.8532383e-03  4.7700093e-03  3.2034004e-03  5.2773365e-04
#   2.8377012e-03 -4.7301338e-03  2.9210635e-03  8.9606794e-05
#  -2.0973324e-03  2.4791420e-04  1.9466926e-03 -9.2817744e-04
#   4.1512307e-03 -1.8547965e-03 -4.5597958e-03  3.4472365e-03
#   2.0618949e-03  2.3951412e-03 -3.4472379e-03  1.7044367e-03
#   8.0634700e-04  1.4665490e-03 -1.7131710e-03 -4.1386005e-03
#   1.6929392e-03  3.6241363e-03  2.5258933e-03  7.5999665e-04]
# /home/komal/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-087fcb9baad6> in <module>
#      17 # model.save('model.bin')
#      18 # load model
# ---> 19 new_model = Word2Vec.load('model.bin')
#      20 # print(new_model)
#
# ~/.local/lib/python3.6/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#    1139         """
#    1140         try:
# -> 1141             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1142
#    1143             # for backward compatibility for `max_final_vocab` feature
#
# ~/.local/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1228
#    1229         """
# -> 1230         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1231         if not hasattr(model, 'ns_exponent'):
#    1232             model.ns_exponent = 0.75
#
# ~/.local/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     600
#     601         """
# --> 602         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     603
#     604     def save(self, fname_or_handle, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     433         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     434
# --> 435         obj = unpickle(fname)
#     436         obj._load_specials(fname, mmap, compress, subname)
#     437         logger.info("loaded %s", fname)
#
# ~/.local/lib/python3.6/site-packages/gensim/utils.py in unpickle(fname)
#    1393
#    1394     """
# -> 1395     with open(fname, 'rb') as f:
#    1396         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1397         if sys.version_info > (3, 0):
#
# ~/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     187         buffering=buffering,
#     188         encoding=encoding,
# --> 189         errors=errors,
#     190     )
#     191     if fobj is not None:
#
# ~/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     360         open_kwargs['errors'] = errors
#     361
# --> 362     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     363
#     364
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.bin'

# %%
#creating a csv file to contain all the conferences TPC details

ipsn_tpc = pd.read_csv('data/Clean_TPC/ipsn_clean.csv')
mobicom_tpc = pd.read_csv('data/Clean_TPC/mobicom_clean.csv')
mobihoc_tpc = pd.read_csv('data/Clean_TPC/mobihoc_clean.csv')
sensys_tpc = pd.read_csv('data/Clean_TPC/sensys_clean.csv')
sigcomm_tpc = pd.read_csv('data/Clean_TPC/sigcomm_clean.csv')

# %%
full_tpc = pd.concat([ipsn_tpc, mobicom_tpc, mobihoc_tpc, sensys_tpc, sigcomm_tpc])
uni_list = set(full_tpc['University/Organization'])

# %%
full_tpc.to_csv('data/Clean_TPC/full_tpc.csv', header = True, index = False)

# %%
uni_list
# Out:
# {nan,
#  'Seoul',
#  'AON Networks',
#  'Vanderbilt University, USA',
#  'University Washington',
#  'Princeton & MSR',
#  'New Jersey Institute of Technology',
#  'Indian Institute of Technology Chennai',
#  'Texas A&M University, USA',
#  'University of Michigan',
#  'Switzerland',
#  'Technicolor Paris Research Center',
#  'Ecole Polytechnique',
#  'University of Illinois Urbana-Champaign',
#  'Vanderbilit/ISIS',
#  'ASU',
#  'University of New South Wales, Australia',
#  'Ben-GurionUniversity of the Negev',
#  'Waterloo',
#  'University of Bonn',
#  'National Academies',
#  'Heriot-Watt University',
#  'KAIST',
#  'NTT Do',
#  'Lehigh University',
#  'University of Pisa',
#  'Ericsson',
#  'California Institute of Technology',
#  'AT&T Research',
#  'Columbia University and VMware',
#  'Univerisity of California San Diego',
#  'Amherst',
#  'Rice University',
#  'UW-Madison',
#  'Brown University',
#  'University of Chicago',
#  'Georgia Tech',
#  'UCL',
#  'UMass-Amherst, USA',
#  'Stony Brook University',
#  'Purdue University, USA',
#  'Ohio State University',
#  'University of Delaware',
#  'PaloAlto Research Center',
#  'IBM T.J. Watson Research',
#  'Buffalo',
#  'GAU',
#  'Washinton University',
#  'University of Pennsylvania',
#  'Apple',
#  'MJMontpetit.com',
#  'CMU',
#  'Universidade Federal de Alagoas, Brazil',
#  'Pittsburgh Supercomputing Center',
#  'Tallinn University of Technology',
#  'Irvine',
#  'Auburn University',
#  'Microsoft Research; SIGMOBILE rep.',
#  'Zurich',
#  'CSIRO, Australia',
#  'University of New South Wales',
#  'Colgate University',
#  'University of Warwick',
#  'Terrestrial Wireless Systems',
#  'University of California at Davis',
#  'BU',
#  'Utah',
#  'Egypt-Japan University of Science and Technology',
#  'Democritus University of Thrace',
#  'George Washington Univ',
#  'University of Rome La Sapienza',
#  'University of Louisiana at Lafayette',
#  'Cornell',
#  'Lucent Technologies',
#  'Alcatel-Lucent',
#  'UWisc',
#  'Tsinghua University',
#  'LG Electronics',
#  'Fujitsu Labs of America',
#  'NEC Labs America',
#  'MPI',
#  'University of Pannonia',
#  'Santa Barbara',
#  'Southern Methodist University',
#  'University of California at Santa Barbara',
#  'University of Catania',
#  'Freie Universitaet Berlin',
#  'Rutgers Univeristy',
#  'Technical University of Denmark',
#  'TIFR Mumbai',
#  'Simon Fraser University',
#  'Georgia Institute of Technology',
#  'Ottawa University',
#  'ClemsonUniversity/Stow Research L.L.C.',
#  'Harbin Institute of Technology',
#  'University of Duisburg-Essen Germany',
#  'University Copenhagen',
#  'QMUL',
#  'ETH Zurich and Caltech',
#  'University of California Berkeley/CITRIS',
#  'Kiyon',
#  'University of Sussex',
#  'Institute of Communication Engineering',
#  'Growth Networks',
#  'UCSD and Google',
#  'University of Crete & FORTH',
#  'Università degli Studi di Milano',
#  'Lancaster University, UK',
#  'University of Maryland',
#  'University Pisa',
#  'Flarion Technologies',
#  'Portland State University',
#  'GM Research Lab',
#  'University of Florida',
#  'Alibaba Group',
#  'Drexel University',
#  'Cisco Systems',
#  'TU Berlin',
#  'University New South Wales',
#  'DoCoMo Labs',
#  'Houston',
#  'University of Central Florida',
#  'Microsoft Research Asia, China',
#  'Austin',
#  'University of Sounthern California',
#  'University Virginia',
#  'University Passo Fundo',
#  'Koc University',
#  'Peking University',
#  'NEC Laboratories',
#  'UOIT',
#  'Korea Advanced Institute of Science and Technology',
#  'OSU',
#  'UCLA/Nomadix',
#  'Georg-August-University of Goettingen',
#  'UFMG',
#  'University of Bologna',
#  'VMware',
#  'IIID, India',
#  'DoCoMo Labs Europe',
#  'Stow Research and Clemson University',
#  'College of William and Mary',
#  'Intel Labs Pittsburgh',
#  'Missouri University of Science and Technology',
#  'York College/CUNY',
#  'IIT-CNR',
#  'Yorktown Heights',
#  'Almaden',
#  'Virginia Institute of Technology',
#  'Michigan State',
#  'Technical University of Darmstadt',
#  'KTH Royal Institute of Technology in Stockholm',
#  'Princeton',
#  'National Institute of Informatics',
#  'UBER',
#  'NUDT',
#  'Universita di Ferrara',
#  'HP Labs',
#  'Oxford University, UK',
#  'Stow Research L.L.C.',
#  'University of Copenhagen',
#  'University of Illinois',
#  'University of Michigan & UC Berkeley',
#  'Technicolor Palo Alto',
#  'IIT Madras',
#  'George Mason University',
#  'Indian Institute of Science Banglore',
#  'ETH, Zurich',
#  'Nokia',
#  'IIT Bombay',
#  'Osaka University',
#  'University of Lisboa',
#  'University of College London',
#  'National Taiwan University',
#  'NIST',
#  'Universityof California Los Angeles',
#  'Università degli Studi di Padova',
#  'University of Leipzig',
#  'BME',
#  'Dartmouth',
#  'Lucent Bell Laboratories',
#  'Temple University, USA',
#  'Stevens Institute of Technology',
#  'Istambul',
#  'University of North Carolina Charlotte',
#  'Bell Labs Alcatel-Lucent',
#  'Devner',
#  'CNR',
#  'Bell Labs Alcatel-Lucent Inc.',
#  'HRL Labs',
#  'CSIRO ICT Centre',
#  'University of Toronto',
#  'Korea University of Technology and Education',
#  'UPMC Sorbonne University & CNRS',
#  'George Washington University',
#  'DIMES Association',
#  'Michigan State University',
#  'Buffalo University',
#  'Scalable Network Technologies',
#  'ICT',
#  'University of CaliforniaLos Angeles',
#  'University of Houston',
#  'Bell-Labs / Alcatel-Lucent',
#  'Cornell University',
#  'HRL Laboratories',
#  'Univesity at Buffalo',
#  'Universidad Autónoma de Madrid',
#  'CISCO',
#  'Tufts University',
#  'NEC',
#  'University of Maryland at College Park',
#  'UNIST',
#  'CNCERT',
#  'Sprint Laboratories',
#  'Tel-Aviv University',
#  'DoCoMo Labs USA',
#  'University of Massachusetts Boston',
#  'NTT DoCoMo USA Labs (US)',
#  'Ann Arbor',
#  "Rome University `La Sapienza'",
#  'University at Buffalo',
#  'University of Houston, USA',
#  "University of Rome 'La Sapienza'",
#  'and Palo Alto Research Center',
#  'QUT',
#  'Swedish Institute of Computer Science, Sweden',
#  'University of Manitoba',
#  'Pittsburgh',
#  'USC/ISI',
#  'Bangalore',
#  'USC/Information Science Institute',
#  'South University of Science and Technology of China',
#  'Bell Labs Research India',
#  'Rochester Institute of Technology',
#  'CNRS',
#  'Univie',
#  'Politecnico di Milano, Italy',
#  'Tsinghua-Berkeley Shenzhen Institute',
#  'Alibaba',
#  'Universidade de Aveiro',
#  'Bell Laboratories',
#  'Politecnico di Milan',
#  'Moteiv',
#  'University Illinois at Urbana-Champaign',
#  'Narus',
#  'Microsoft Research.',
#  'Microsoft Research and Matt Welsh',
#  'University of Californiaat Davis',
#  'RWTH Aachen University',
#  'Brooklyn College',
#  'NEC Labs Princeton',
#  'NTU',
#  'Nokia Research',
#  'Bilkent University',
#  'University',
#  'VMware Research',
#  'EPM',
#  'inc.',
#  'University or Minnesota',
#  'Zhejiang University',
#  'University of California Berkeley and ICSI',
#  'Hitachi Research',
#  'IIIT Delhi',
#  'Montana State University',
#  'NASA Jet Propulsion Labortory',
#  'HIIT',
#  'Bell Labs Research',
#  'Rutgers',
#  'Ohio State',
#  'Institute IMDEA Networks',
#  'Università di Catania',
#  'Universitá di\xa0Roma "La\xa0Sapienza"',
#  'ACIRI/ICSI',
#  'University of North Carolina, Chapel Hill',
#  'University of Maryland College\xa0Park',
#  'USC/Information Sciences Institute',
#  'SUNY Stony Brook',
#  'Microsoft - USA',
#  'University College Dublin',
#  'University of Massachusetts Amherst',
#  'University of British Columbia',
#  'IBM T. J.Watson',
#  'Carnegie Mellon University ',
#  'IBM TJ Watson Research Center',
#  'Marconi Research Center',
#  'Swedish Institute of Computer Science',
#  'Clemson University',
#  'SRI',
#  'UPMC/LIP6',
#  'University of California San Diego',
#  'University of California at Berkley',
#  'AT&T Labs',
#  'Siemens USA',
#  'University of Nevada',
#  'MD2K',
#  'UK',
#  'Santa Cruz/PARC',
#  'Raytheon BBN',
#  'Polytechnic of Turin',
#  'TU Graz ',
#  'University of Southern California',
#  'Rome University "La Sapienza"',
#  'NTT DoCoMo Euro-Labs',
#  'Old Dominion University',
#  'Cornell Tech',
#  'HKUST',
#  'University of Passau',
#  'Cape Peninsula University of Technology',
#  'SUNY Binghamton',
#  'LIP6 / CNRS',
#  'UniversityPennsylvania',
#  'NC State University',
#  'Korea University',
#  'Arnaud',
#  'DIKU',
#  'University of Hong Kong',
#  'U. Western Australia',
#  'Telefonica Research',
#  'Georgia\xa0 Institute of Technology',
#  'Worcester Polytechnic Institute',
#  'Max Planck Institute',
#  'Aachen University',
#  'LUMS',
#  'University of Duisburg-Essen and Fraunhofer IAIS',
#  'IIT Hyderabad',
#  'Telefonica I and D Spain',
#  'Technische Universität Braunschweig',
#  'Auckland',
#  'Cork',
#  'University of California Santa\xa0Cruz',
#  'University of Luebeck',
#  'Simula Research Laboratory',
#  'Microsoft Research China',
#  'Agilent Technologies',
#  'Brown',
#  'Politecnico di Torino',
#  'University of Patras and CTI',
#  'ETH',
#  'BUAA',
#  'Southeast University',
#  'Hewlett-Packard Labs',
#  'Univeristy of Southern California',
#  'University of Maryland College Park',
#  'Deutsche Telekom Laboratories / TU-Berlin',
#  'Lip6',
#  'State University of New\xa0York at Stony\xa0Brook (US)',
#  'University of Saarbruecken',
#  'University of Alabama',
#  'Royal Institute of Technology',
#  'NEC Laboratories America',
#  'University of California Santa Cruz',
#  'University of Luebeck and ETH Zurich',
#  'BBN Technologies',
#  'Universityof California San Diego',
#  'DoCoMo USA Labs',
#  'National Chiao-Tung University, Taiwan',
#  'Middle East Technical University',
#  'University of Twente',
#  'University of Rome "La\xa0Sapienza"',
#  'Chinese University of Hong Kong',
#  'Cambridge University',
#  'AT&T Bell Labs',
#  'UMPC LIP6',
#  'Telcordia Technologies',
#  'Nanjing University',
#  'IIT Delhi',
#  'Illinois Institute of Technology',
#  'Chungnam University',
#  'Yale',
#  'Unicamp',
#  'Karlsruhe',
#  'San Diego',
#  'Indian Institute of Technology Madras',
#  'General Motors',
#  'Max Planck',
#  'Hong Kong Universityof Science and Technology',
#  'Dartmouth University',
#  'Deutsche Telekom',
#  'University of New South Wales, and NICTA',
#  'Sentilla',
#  'Bell Lab',
#  'MeitY',
#  'NYU Polytechnic School of Engineering',
#  'University of Wisconsin - Madison',
#  'Imperial College',
#  'Columbia University. USA',
#  'INRIA',
#  'University Chicago',
#  'AEUB',
#  'University of California-Santa Barbara',
#  "'La Sapienza'",
#  'Chalmers University of Technology',
#  'Nokia Research Center',
#  'Dartmouth College',
#  'Sun',
#  'unaffiliated',
#  'Tsinghua',
#  'Cairo University and Nile University',
#  'University of Utah',
#  'Telcordia',
#  'University of California at Berkeley',
#  'Teranovi Technologies',
#  'University Oregon',
#  'Google & University of Washington',
#  'University of Waterloo',
#  'TIFT Mumbai',
#  'Manhattan College',
#  'University College London',
#  'University of Roma Tre, Italy',
#  'University of Paderborn',
#  'LUMS, Pakistan',
#  'Consiglio Nazionale delle Ricerche',
#  'UNSW',
#  'Hong Kong Polytechnic University',
#  'University of Rochester',
#  'Inc. / UCLA',
#  'Massachusetts Institute of TechnologyACS Chief Operating Officer',
#  'University of Illinois Chicago',
#  'Microsoft Research - Inria Joint Centre',
#  'Nyansa Inc.',
#  'Princeton University',
#  'BBN',
#  'IISc Bangalore',
#  'Binghamton University',
#  'National Chiao Tung University',
#  'University of Helsinki',
#  'Oregon State University',
#  'Boston University',
#  'Hungary and Unicamp',
#  'Intel Research',
#  'University of North Carolina at Charlotte',
#  'Upitt',
#  'College Park',
#  'AT&T Labs-Research',
#  'Davis',
#  'Clemson Univ and Stow research',
#  'Oculus',
#  'University of Kiel',
#  'Turin Networks and CMU',
#  'Uppsala University',
#  'University of North Carolina',
#  'USC/Information Sciences Institute (US)',
#  'MPI-SWS',
#  'Shanghai Jiao Tong University',
#  'NIIT University',
#  'Columbia',
#  'University of Rome',
#  'University of Memphis',
#  'University Sydney',
#  'Johns Hopkins University',
#  'CAIDA/UCSD San Diego',
#  'IMDEA Networks Institute',
#  'University of Hawaii',
#  'NCTU',
#  'IBM Thomas J. Watson Research Center',
#  'IUPUI',
#  'Academica Sinica',
#  'SUNY at Buffalo',
#  'University of California San Diego ECE',
#  'Lancaster University',
#  'Graz University of Technology',
#  'Rutgers University',
#  'Lumigent',
#  'Bogazici University',
#  'University of Kentucky',
#  'Caltech',
#  'University of South Carolina',
#  'ICIR',
#  'MPI for Software Systems',
#  'Facebook',
#  'University of Rhode Island',
#  'ABB Corporate Research',
#  'TeraOptic Networks',
#  'DOCOMO Innovations',
#  'SICS / Politecnico di Milano',
#  'University of Wisconsin Madison',
#  'University of Lubeck',
#  'San Diego Research Center',
#  'NSF and University of Pittsburgh',
#  'Jiao Tong University',
#  'IBM T. J. Watson Research Center',
#  'CIPO',
#  'Cisco Meraki',
#  'Madrid Institute for Advanced Studies in Networks (IMDEA Networks)',
#  'University of Massachusett Amherst',
#  'Yokohama National University',
#  'Maynooth University',
#  'Macao Polytechnic Institute',
#  'Northern Arizona University',
#  'HP Laboratories',
#  'University of Michigan Dearborn',
#  'Harvard',
#  'Aalto University',
#  'Paris 11 University',
#  'California State University',
#  'SUNY at Buffalo, USA',
#  'Colorado School of Mines',
#  'University of Adelaide',
#  'University of California Riverside',
#  'BBN Technology',
#  'CreateNet',
#  'Memphis',
#  'Technical University of Dortmund',
#  'Sharp Labs',
#  'University of Illinois Urbana Champaign/Massachusetts Institute of Technology',
#  'DoCoMo Eurolabs',
#  'IBM T.J. Watson Research Center',
#  'University of Massachusetts at Amherst',
#  'Copenhagen',
#  'University of Maryland Baltimore',
#  'Universita di Pisa',
#  'IEEE',
#  'University of Illinois Urbana Champaign',
#  'University of Napoli',
#  'Cisco',
#  'University of Murcia',
#  'Athens University of Economics and Business',
#  'National University of Computer and Emerging Sciences, Pakistan',
#  'NRL',
#  'CNRS and UMPC Sorbonne Universities',
#  'TU Darmstadt',
#  'Nanyang Technological University',
#  'UMass Amherst',
#  'University of Arizona',
#  'McGill',
#  'Google Brain',
#  'Deep Field Networks',
#  'University of Roma Tor Vergata',
#  'University of Oulu',
#  'KTH Royal Institute of Technology',
#  'Intel Research/Carnegie Mellon University',
#  'Reykjavik University',
#  'Korea Electronics Technology Institute',
#  'University of Naples',
#  'Microsoft',
#  'The Hong Kong Polytechnic University',
#  'USTC',
#  'Intel Research Cambridge',
#  'University of California-Berkely',
#  'Group Strategy & Innovation',
#  'EPFL',
#  'University of Szeged, Hungary',
#  'SUNY Stony Brook University',
#  'Paris',
#  'Telcordia Tech.',
#  'Berkeley',
#  'Telefonika',
#  'Alcatel-Lucent Bell Laboratories',
#  'EURECOM',
#  'Toyota InfoTechnology Center',
#  'IBM Zurich',
#  'Amazon',
#  'Washington University',
#  'University of California Davis',
#  'TU Graz / CSH Vienna',
#  'University of Massachusetts-Amherst',
#  'University of California San\xa0Diego',
#  'Stow Research',
#  'Juniper Networks',
#  'Shanghai Jiangtong University',
#  'Michigan State University, USA',
#  'SUPSI',
#  'RWTH Aachen',
#  'NICTA',
#  'Keio University',
#  'Chulalongkorn U.',
#  'University Texas at Arlington',
#  'INRIA Lille-Nord Europe',
#  'Korean Advanced Institute of Science and Technology',
#  'Nest Labs',
#  'University of Virgnia',
#  'SUNY Buffalo',
#  'University of Colorado Boulder & UC Denver',
#  'HP labs',
#  'T-Labs',
#  'Yonsei University',
#  'Intel Labs Settle',
#  'Eurecom',
#  'Netflix',
#  'Pisa, Italy',
#  'National University of Singapore',
#  'Microsoft Research Asia',
#  'Tsinghua University and Tsinghua-Berkeley Shenzhen Institute',
#  'Bell-labs',
#  'INRIA-ENS',
#  'Pennsylvania State University',
#  'University of Texas Austin',
#  'Technische University Berlin',
#  'London',
#  'Stow Research/Clemson University',
#  'University of California Santa Barbara',
#  'University of California Los\xa0Angeles',
#  'Shizuoka University',
#  'U. Karlsruhe',
#  'IMDEA Networks',
#  'Supelec',
#  'Carleton University',
#  'University of Ottawa',
#  'Macquarie University',
#  'Samsung’s Software R&D Center',
#  'OGI School of Engineering',
#  'Cornell Universiity',
#  'Broadcom',
#  'PA',
#  'Nile University',
#  'Lincoln',
#  'BUPT',
#  'TU Dresden',
#  'IBM',
#  'IllinoisInstitute of Technology',
#  'Intel / University of Washington',
#  'Egypt- Japan University of Science and Technology',
#  'INRIA Saclay - Ile-de-France',
#  'UFMG, Brazil',
#  'University of Wurzburg',
#  'IMEC Belgium',
#  'Airdefense',
#  'Universita di Roma Tor Vergata',
#  'Intel Research Pittsburgh',
#  'University of Porto',
#  'Bell Labs Alcatel-Lucent & TU Eindhoven',
#  'US Sprint',
#  'Intel Cambridge Research Lab',
#  'HUJI',
#  'NetApp',
#  'University Paris',
#  'University of Massachusetts - Amherst',
#  'Clemson University and Stow Research L.L.C.',
#  'ATT Labs Research',
#  'SUNYIT',
#  'Albert-Ludwigs-Universität',
#  'Vienna Univ. of Technology, Austria',
#  'Hewlett Packard Labs',
#  'SUNY',
#  'Sprint Advanced Technology Labs',
#  'Intel Labs Berkeley',
#  'University of Tennessee',
#  'Reykjavik University, Iceland',
#  'Penn State University',
#  'Baltimore County',
#  'WUSTL',
#  'Massachusetts Institute of Technology and Georgia Tech',
#  'Politecnico di Milano, Italy and SICS Swedish ICT',
#  'Technische Universität Berlin',
#  'Morgan Stanley',
#  'Columbia University Do Young Eun',
#  'Tohoku University',
#  'Stony Brook',
#  'University Western Australia',
#  'EPFL and University of California in Berkeley',
#  'MSR',
#  'Washington University in St. Louis',
#  'TCS Research & Innovation',
#  'NetLab-SUPSI',
#  'Budapest University of Technology and Economics',
#  'TU Berlin, Germany',
#  'Qualcomm',
#  'City University of Hong Kong',
#  'University Pennsylvania',
#  'IBM Daksh',
#  'IMT',
#  'RISE SICS',
#  'University of Virginia, USA',
#  'University of Brescia',
#  'Hong Kong Univ. of Science and Technology',
#  'Univeristy of Texas Austin',
#  'Singapore University of Technology and Design',
#  'University of Graz',
#  'UT',
#  'IIJ Research Laboratory',
#  'Princeton University and University College London',
#  'VMWare',
#  'University of Innsbruck',
#  'Google/University of California San Diego',
#  'National Polytechnic University',
#  'Fraunhofer IZM',
#  'Vanderbilt University ',
#  'Soroco',
#  'University of New South Wales and CSIRO',
#  'Cleveland State University',
#  'École Polytechnique de Montréal',
#  'University of Athens',
#  'University ofIllinois at Urbana-Champaign',
#  'Las Vegas',
#  'Indiana University',
#  'Create-Net',
#  'Nokia Brazil',
#  'Haier',
#  'Purdue',
#  'University of Szeged',
#  'Luleå University of Technology',
#  'NSFC',
#  'Technion',
#  'Microsoft Research, USA',
#  'IBM Watson Lab',
#  'Indian Institute of Technology in Kanpur India',
#  'MSU and ARCCN',
#  'Air Force Institute of Technology',
#  'University of Tokyo',
#  'Sprint ATL',
#  'Duke and Akamai',
#  'GWU',
#  'University of Souther California / Information Sciences Institute',
#  'Microsoft Research Cambridge',
#  'Florida Atlantic University',
#  'Lancaster University (UK) and University of Arizona (US)',
#  'Seoul National University',
#  'University of Southampton',
#  'University Pierre et Marie Curie',
#  'University of London',
#  'WPI',
#  'University of San Diego',
#  'California Institute of Technology / ETH - Zurich',
#  'Intel Labs',
#  'University of Stuttgart',
#  'University of Science and Technology of China',
#  'University of Michigan/University of Virginia',
#  'Sweden and Politecnico di Milano',
#  'University of Penn.',
#  'University of New South Wales and NICTA',
#  'Wisconsin',
#  'Bell Labs',
#  'University of Iowa',
#  'University of Nebraska-Lincoln',
#  'SICS',
#  'SUNY at Stony Brook',
#  'Palo Alto Research Center',
#  'University of Nebraska',
#  'University of Surrey',
#  'The Ohio State University',
#  'MSR Cambridge',
#  'Hewlett-Packard Laboratories',
#  'Tyndall Institute',
#  'University of Edinburgh',
#  'Army Research Lab',
#  'US Naval Research Laboratory',
#  'Telecom ParisTech',
#  'Yale University',
#  'LinkedIn',
#  'Italy',
#  'Duke University',
#  'ICT CAS',
#  'University Colorado',
#  'CAIDA',
#  'Universitat Politècnica de Catalunya',
#  'National Tsing Hua University',
#  'Chulalongkorn University',
#  'tardo',
#  'Università di Ferrara',
#  'University Pierre & Marie Curie',
#  'ETH Zurich & University of Bologna',
#  'UCSD',
#  'SWITCH',
#  'University of Lancaster',
#  'Microsoft Research Redmond',
#  'NTT Docomo Labs',
#  'Sandia National Labs',
#  'Chung-Ang University',
#  'SICS, Sweden',
#  'Korea UMD',
#  'University of Arkansas',
#  'University of Texas Arlington',
#  'University of Michigan Ann Arbor',
#  'Gatech',
#  'Politecnico di Milan and RISE SICS',
#  'Meru Networks',
#  'University of Texas Dallas',
#  'Schiller',
#  'Hitachi Research, Tokyo',
#  'Stonybrook',
#  'Northwestern',
#  'Lund',
#  'Ericsson Research',
#  'CA',
#  'Styra',
#  'KTH, Sweden',
#  'NASA/BBN',
#  'University College Cork, Ireland',
#  'University of California at Los Angeles',
#  'University of Lyon',
#  'Tyndall Institute, Ireland',
#  'Commonwealth Scientific and Industrial Research Organisation',
#  'Washington State University',
#  'Northeastern University',
#  'ReefEdge',
#  'University of South Carolina Beaufort',
#  'Sabanci University',
#  'UMich',
#  'AT&T Labs -- Research',
#  'University of Technology Sydney',
#  'Bombay',
#  'KTH, Royal Institute of Technology',
#  'JPEO JTRS',
#  'Germany',
#  'MIT Lincoln Lab',
#  'Carnegie Mellon University',
#  'New Hampshire',
#  'University of Lubeck and ETH Zurich',
#  'University of San Francisco',
#  'ISI/USC',
#  'Sapienza',
#  'NUIM',
#  'Università di Milano',
#  'A16Z',
#  'Samsung US',
#  'Deutsche Telekom Labs & TU Berlin',
#  'TU',
#  'IMEC',
#  'Ben Gurion University',
#  'KAIST, Korea',
#  'NSF and University of Pittsburgh (US)',
#  'Boeing',
#  'University Minnesota',
#  'Northwestern University',
#  'University of Cambridge',
#  'University of California',
#  'Chiasserini Polytechnic of Turin',
#  'University Texas',
#  'University of Cincinnati',
#  'Loughborough University',
#  'University of California Berkeley',
#  'University of California Los Angeles',
#  'Indian Institute of Technology',
#  'Wayne State University',
#  'University of Duisburg Essen',
#  'Istanbul Technical University',
#  'Texas A&M University',
#  'Meraki',
#  'NUI Maynooth',
#  'Microsoft Corporation',
#  'Swiss Federal Institute of Technology',
#  'University of Goettingen',
#  'UC Santa Barbara',
#  'Institute of Computing Technology, Chinese Academy of Sciences',
#  'Academic Sinica',
#  'Advanced Digital Sciences Center',
#  'Cambridge',
#  'University of Ferrara',
#  'Penn State',
#  'Hong Kong UST',
#  'University of ssaly',
#  'CERTH',
#  'FBK',
#  'Boston University and Network Appliance',
#  'Madison',
#  'Kiyon Inc.',
#  'TU Delft',
#  'Inria, France',
#  'Portland State',
#  'Hitachi',
#  'Indian Institute of Information Technology (IIIT)',
#  'Rutgers University, USA',
#  'IBM China Research Labs',
#  'Microsoft Research India',
#  'National University of\xa0Mexico',
#  'Riverbed Technology',
#  'Stow Research LLC',
#  'New York University',
#  'Booz Allen Hamilton',
#  'University of Virginia',
#  'UWaterloo',
#  'Google and University of Washington',
#  'Sound Life Sciences',
#  'Tata Institute of Fundamental Research',
#  'Purdue University',
#  'Virginia',
#  'University of Oxford and Samsung AI',
#  'Duke Univeristy / Akamai Technologies',
#  'Vanderbilt University',
#  'University of California Merced',
#  'MPI-SWS/Google',
#  'CityU',
#  'Brocade',
#  'Caltech/IIT Madras',
#  'Università della Svizzera italiana',
#  'IIT-Madras',
#  'DARPA',
#  'SUNY Stonybrook',
#  'HP Laboratories (US)',
#  'University of Wisconsin at Madison',
#  'College of Williamand Mary',
#  'NSF',
#  'Shanghai JiaoTong',
#  'Duke University and Akamai Technologies',
#  'Telefonica',
#  'Grenoble INP-Ensimag',
#  'Thomson',
#  'University of Innsbruck, Austria',
#  'Queensland University of Technology',
#  'Imperial College London',
#  'Microsoft Research, China',
#  'Intentionet',
#  'Michigan',
#  'Barefoot',
#  'Redback Networks',
#  'Stow Research and Clemson Univ.',
#  'IIIT-Delhi',
#  'CUNY',
#  'University at Albany',
#  'University of Crete and FORTH',
#  'National Technical U of Athens',
#  'University of Oxford and Nokia Bell Labs',
#  'University ofMichigan',
#  'University of Birmingham',
#  'Ben-Gurion University of the Negev',
#  'University College London and Nokia Bell Labs',
#  'Fujitsu Laboratories of America',
#  'Ajou University',
#  "King's College London",
#  "Laboratoire d'Informatique de Paris 6",
#  'Santa Cruz',
#  'Facebook Inc.',
#  'University of Dortmund',
#  'AT&T Labs - Research',
#  'Universit "La Sapienza"',
#  'Technicolor',
#  'IIT Kharagpur',
#  'State University of New York at Buffalo',
#  'Niksun',
#  'University of Texas at Dallas, USA',
#  'West Chester University',
#  'Redmond',
#  'Universidad de Valencia',
#  'GM Research',
#  'Nicira Networks',
#  'USC/UCSD',
#  'Stanford',
#  'University of Massachusetts',
#  'UCLA',
#  'NBT Technologies',
#  'Mumbai',
#  'ICT CAS, China',
#  'ICSI',
#  'Salerno',
#  'Duke/Akamai',
#  'Army Research Laboratories',
#  'AT&T',
#  'Shanghai Jiaotong University',
#  'KAUST',
#  'TU Braunschweig',
#  'Università di Roma "La Sapienza"',
#  'IMDEA',
#  'Los Angeles',
#  'Lockheed Martin Advanced Technology Center',
#  'Intel Corporation',
#  'Lausanne',
#  'University of California Davis and SynapSense',
#  'Rice/Technion',
#  'KETI',
#  'University of Sydney',
#  'UTwente',
#  'Telcordia Inc.',
#  'CSIRO',
#  'Rensselaer Polytechnic Institute',
#  'Deutsche Telekom Laboratories',
#  'Qualcomm Inc.',
#  'Università di Pisa',
#  'National and Kapodistrian University of Athens',
#  'ISI',
#  'IBM India Research Lab',
#  'National Chiao-Tung University',
#  'Intel Research Berkeley',
#  'UPB',
#  "Universita' degli Studi di Roma",
#  'CNR - IIT',
#  'HongKong City University',
#  'Clemson University and Stow Research L.L.C',
#  'Hamilton Institute',
#  'University of Chinese Academy of Science',
#  'Carnegie Mellon',
#  'University of Wisconsin',
#  'NTT Docomolabs',
#  'TU Eindhoven',
#  'NIKSUN',
#  'Google',
#  'University of Canterbury, New Zealand',
#  'McGill University',
#  'University of Palermo',
#  'Bell Labs India',
#  'Sapienza University of Rome',
#  'Rome University',
#  'Iowa State University',
#  'Atos',
#  'Universidad Carlos III de Madrid',
#  'Nanyang Technical University',
#  'Microsoft - England',
#  'HPE',
#  'UT Austin',
#  'Technion – Israel Institute of Technology',
#  'Korean University',
#  'University of Pittsburgh',
#  'Uber Inc.',
#  'UCSC',
#  'Raytheon BBN Technologies',
#  'Deutsche Telekom Labs/TU-Berlin',
#  'Arbor Networks',
#  'Colorado State University',
#  'University of Melbourne',
#  'Technical University of Berlin',
#  'UW',
#  ...}

# %%
for uni in uni_list:
    if type(uni) == str:
        if uni.lower().find('nec') > -1:
            print(uni)
# Out:
# NEC Labs America
# NEC Laboratories
# NEC
# NEC Labs Princeton
# NEC Laboratories America
# NEC Labs
# NEC Research Europe
# NEC LABS

# %%
uni_df = {}
for uni in uni_list:
#     print(uni)
#     print(full_tpc[full_tpc['University/Organization'] == uni])
    uni_df[uni] = full_tpc[full_tpc['University/Organization'] == uni]

# %%
uni = list(uni_df.keys())
# uni = ['app', 'zwe', 'bsd']
uni
# Out:
# [nan,
#  'Seoul',
#  'AON Networks',
#  'Vanderbilt University, USA',
#  'University Washington',
#  'Princeton & MSR',
#  'New Jersey Institute of Technology',
#  'Indian Institute of Technology Chennai',
#  'Texas A&M University, USA',
#  'University of Michigan',
#  'Switzerland',
#  'Technicolor Paris Research Center',
#  'Ecole Polytechnique',
#  'University of Illinois Urbana-Champaign',
#  'Vanderbilit/ISIS',
#  'ASU',
#  'University of New South Wales, Australia',
#  'Ben-GurionUniversity of the Negev',
#  'Waterloo',
#  'University of Bonn',
#  'National Academies',
#  'Heriot-Watt University',
#  'KAIST',
#  'NTT Do',
#  'Lehigh University',
#  'University of Pisa',
#  'Ericsson',
#  'California Institute of Technology',
#  'AT&T Research',
#  'Columbia University and VMware',
#  'Univerisity of California San Diego',
#  'Amherst',
#  'Rice University',
#  'UW-Madison',
#  'Brown University',
#  'University of Chicago',
#  'Georgia Tech',
#  'UCL',
#  'UMass-Amherst, USA',
#  'Stony Brook University',
#  'Purdue University, USA',
#  'Ohio State University',
#  'University of Delaware',
#  'PaloAlto Research Center',
#  'IBM T.J. Watson Research',
#  'Buffalo',
#  'GAU',
#  'Washinton University',
#  'University of Pennsylvania',
#  'Apple',
#  'MJMontpetit.com',
#  'CMU',
#  'Universidade Federal de Alagoas, Brazil',
#  'Pittsburgh Supercomputing Center',
#  'Tallinn University of Technology',
#  'Irvine',
#  'Auburn University',
#  'Microsoft Research; SIGMOBILE rep.',
#  'Zurich',
#  'CSIRO, Australia',
#  'University of New South Wales',
#  'Colgate University',
#  'University of Warwick',
#  'Terrestrial Wireless Systems',
#  'University of California at Davis',
#  'BU',
#  'Utah',
#  'Egypt-Japan University of Science and Technology',
#  'Democritus University of Thrace',
#  'George Washington Univ',
#  'University of Rome La Sapienza',
#  'University of Louisiana at Lafayette',
#  'Cornell',
#  'Lucent Technologies',
#  'Alcatel-Lucent',
#  'UWisc',
#  'Tsinghua University',
#  'LG Electronics',
#  'Fujitsu Labs of America',
#  'NEC Labs America',
#  'MPI',
#  'University of Pannonia',
#  'Santa Barbara',
#  'Southern Methodist University',
#  'University of California at Santa Barbara',
#  'University of Catania',
#  'Freie Universitaet Berlin',
#  'Rutgers Univeristy',
#  'Technical University of Denmark',
#  'TIFR Mumbai',
#  'Simon Fraser University',
#  'Georgia Institute of Technology',
#  'Ottawa University',
#  'ClemsonUniversity/Stow Research L.L.C.',
#  'Harbin Institute of Technology',
#  'University of Duisburg-Essen Germany',
#  'University Copenhagen',
#  'QMUL',
#  'ETH Zurich and Caltech',
#  'University of California Berkeley/CITRIS',
#  'Kiyon',
#  'University of Sussex',
#  'Institute of Communication Engineering',
#  'Growth Networks',
#  'UCSD and Google',
#  'University of Crete & FORTH',
#  'Università degli Studi di Milano',
#  'Lancaster University, UK',
#  'University of Maryland',
#  'University Pisa',
#  'Flarion Technologies',
#  'Portland State University',
#  'GM Research Lab',
#  'University of Florida',
#  'Alibaba Group',
#  'Drexel University',
#  'Cisco Systems',
#  'TU Berlin',
#  'University New South Wales',
#  'DoCoMo Labs',
#  'Houston',
#  'University of Central Florida',
#  'Microsoft Research Asia, China',
#  'Austin',
#  'University of Sounthern California',
#  'University Virginia',
#  'University Passo Fundo',
#  'Koc University',
#  'Peking University',
#  'NEC Laboratories',
#  'UOIT',
#  'Korea Advanced Institute of Science and Technology',
#  'OSU',
#  'UCLA/Nomadix',
#  'Georg-August-University of Goettingen',
#  'UFMG',
#  'University of Bologna',
#  'VMware',
#  'IIID, India',
#  'DoCoMo Labs Europe',
#  'Stow Research and Clemson University',
#  'College of William and Mary',
#  'Intel Labs Pittsburgh',
#  'Missouri University of Science and Technology',
#  'York College/CUNY',
#  'IIT-CNR',
#  'Yorktown Heights',
#  'Almaden',
#  'Virginia Institute of Technology',
#  'Michigan State',
#  'Technical University of Darmstadt',
#  'KTH Royal Institute of Technology in Stockholm',
#  'Princeton',
#  'National Institute of Informatics',
#  'UBER',
#  'NUDT',
#  'Universita di Ferrara',
#  'HP Labs',
#  'Oxford University, UK',
#  'Stow Research L.L.C.',
#  'University of Copenhagen',
#  'University of Illinois',
#  'University of Michigan & UC Berkeley',
#  'Technicolor Palo Alto',
#  'IIT Madras',
#  'George Mason University',
#  'Indian Institute of Science Banglore',
#  'ETH, Zurich',
#  'Nokia',
#  'IIT Bombay',
#  'Osaka University',
#  'University of Lisboa',
#  'University of College London',
#  'National Taiwan University',
#  'NIST',
#  'Universityof California Los Angeles',
#  'Università degli Studi di Padova',
#  'University of Leipzig',
#  'BME',
#  'Dartmouth',
#  'Lucent Bell Laboratories',
#  'Temple University, USA',
#  'Stevens Institute of Technology',
#  'Istambul',
#  'University of North Carolina Charlotte',
#  'Bell Labs Alcatel-Lucent',
#  'Devner',
#  'CNR',
#  'Bell Labs Alcatel-Lucent Inc.',
#  'HRL Labs',
#  'CSIRO ICT Centre',
#  'University of Toronto',
#  'Korea University of Technology and Education',
#  'UPMC Sorbonne University & CNRS',
#  'George Washington University',
#  'DIMES Association',
#  'Michigan State University',
#  'Buffalo University',
#  'Scalable Network Technologies',
#  'ICT',
#  'University of CaliforniaLos Angeles',
#  'University of Houston',
#  'Bell-Labs / Alcatel-Lucent',
#  'Cornell University',
#  'HRL Laboratories',
#  'Univesity at Buffalo',
#  'Universidad Autónoma de Madrid',
#  'CISCO',
#  'Tufts University',
#  'NEC',
#  'University of Maryland at College Park',
#  'UNIST',
#  'CNCERT',
#  'Sprint Laboratories',
#  'Tel-Aviv University',
#  'DoCoMo Labs USA',
#  'University of Massachusetts Boston',
#  'NTT DoCoMo USA Labs (US)',
#  'Ann Arbor',
#  "Rome University `La Sapienza'",
#  'University at Buffalo',
#  'University of Houston, USA',
#  "University of Rome 'La Sapienza'",
#  'and Palo Alto Research Center',
#  'QUT',
#  'Swedish Institute of Computer Science, Sweden',
#  'University of Manitoba',
#  'Pittsburgh',
#  'USC/ISI',
#  'Bangalore',
#  'USC/Information Science Institute',
#  'South University of Science and Technology of China',
#  'Bell Labs Research India',
#  'Rochester Institute of Technology',
#  'CNRS',
#  'Univie',
#  'Politecnico di Milano, Italy',
#  'Tsinghua-Berkeley Shenzhen Institute',
#  'Alibaba',
#  'Universidade de Aveiro',
#  'Bell Laboratories',
#  'Politecnico di Milan',
#  'Moteiv',
#  'University Illinois at Urbana-Champaign',
#  'Narus',
#  'Microsoft Research.',
#  'Microsoft Research and Matt Welsh',
#  'University of Californiaat Davis',
#  'RWTH Aachen University',
#  'Brooklyn College',
#  'NEC Labs Princeton',
#  'NTU',
#  'Nokia Research',
#  'Bilkent University',
#  'University',
#  'VMware Research',
#  'EPM',
#  'inc.',
#  'University or Minnesota',
#  'Zhejiang University',
#  'University of California Berkeley and ICSI',
#  'Hitachi Research',
#  'IIIT Delhi',
#  'Montana State University',
#  'NASA Jet Propulsion Labortory',
#  'HIIT',
#  'Bell Labs Research',
#  'Rutgers',
#  'Ohio State',
#  'Institute IMDEA Networks',
#  'Università di Catania',
#  'Universitá di\xa0Roma "La\xa0Sapienza"',
#  'ACIRI/ICSI',
#  'University of North Carolina, Chapel Hill',
#  'University of Maryland College\xa0Park',
#  'USC/Information Sciences Institute',
#  'SUNY Stony Brook',
#  'Microsoft - USA',
#  'University College Dublin',
#  'University of Massachusetts Amherst',
#  'University of British Columbia',
#  'IBM T. J.Watson',
#  'Carnegie Mellon University ',
#  'IBM TJ Watson Research Center',
#  'Marconi Research Center',
#  'Swedish Institute of Computer Science',
#  'Clemson University',
#  'SRI',
#  'UPMC/LIP6',
#  'University of California San Diego',
#  'University of California at Berkley',
#  'AT&T Labs',
#  'Siemens USA',
#  'University of Nevada',
#  'MD2K',
#  'UK',
#  'Santa Cruz/PARC',
#  'Raytheon BBN',
#  'Polytechnic of Turin',
#  'TU Graz ',
#  'University of Southern California',
#  'Rome University "La Sapienza"',
#  'NTT DoCoMo Euro-Labs',
#  'Old Dominion University',
#  'Cornell Tech',
#  'HKUST',
#  'University of Passau',
#  'Cape Peninsula University of Technology',
#  'SUNY Binghamton',
#  'LIP6 / CNRS',
#  'UniversityPennsylvania',
#  'NC State University',
#  'Korea University',
#  'Arnaud',
#  'DIKU',
#  'University of Hong Kong',
#  'U. Western Australia',
#  'Telefonica Research',
#  'Georgia\xa0 Institute of Technology',
#  'Worcester Polytechnic Institute',
#  'Max Planck Institute',
#  'Aachen University',
#  'LUMS',
#  'University of Duisburg-Essen and Fraunhofer IAIS',
#  'IIT Hyderabad',
#  'Telefonica I and D Spain',
#  'Technische Universität Braunschweig',
#  'Auckland',
#  'Cork',
#  'University of California Santa\xa0Cruz',
#  'University of Luebeck',
#  'Simula Research Laboratory',
#  'Microsoft Research China',
#  'Agilent Technologies',
#  'Brown',
#  'Politecnico di Torino',
#  'University of Patras and CTI',
#  'ETH',
#  'BUAA',
#  'Southeast University',
#  'Hewlett-Packard Labs',
#  'Univeristy of Southern California',
#  'University of Maryland College Park',
#  'Deutsche Telekom Laboratories / TU-Berlin',
#  'Lip6',
#  'State University of New\xa0York at Stony\xa0Brook (US)',
#  'University of Saarbruecken',
#  'University of Alabama',
#  'Royal Institute of Technology',
#  'NEC Laboratories America',
#  'University of California Santa Cruz',
#  'University of Luebeck and ETH Zurich',
#  'BBN Technologies',
#  'Universityof California San Diego',
#  'DoCoMo USA Labs',
#  'National Chiao-Tung University, Taiwan',
#  'Middle East Technical University',
#  'University of Twente',
#  'University of Rome "La\xa0Sapienza"',
#  'Chinese University of Hong Kong',
#  'Cambridge University',
#  'AT&T Bell Labs',
#  'UMPC LIP6',
#  'Telcordia Technologies',
#  'Nanjing University',
#  'IIT Delhi',
#  'Illinois Institute of Technology',
#  'Chungnam University',
#  'Yale',
#  'Unicamp',
#  'Karlsruhe',
#  'San Diego',
#  'Indian Institute of Technology Madras',
#  'General Motors',
#  'Max Planck',
#  'Hong Kong Universityof Science and Technology',
#  'Dartmouth University',
#  'Deutsche Telekom',
#  'University of New South Wales, and NICTA',
#  'Sentilla',
#  'Bell Lab',
#  'MeitY',
#  'NYU Polytechnic School of Engineering',
#  'University of Wisconsin - Madison',
#  'Imperial College',
#  'Columbia University. USA',
#  'INRIA',
#  'University Chicago',
#  'AEUB',
#  'University of California-Santa Barbara',
#  "'La Sapienza'",
#  'Chalmers University of Technology',
#  'Nokia Research Center',
#  'Dartmouth College',
#  'Sun',
#  'unaffiliated',
#  'Tsinghua',
#  'Cairo University and Nile University',
#  'University of Utah',
#  'Telcordia',
#  'University of California at Berkeley',
#  'Teranovi Technologies',
#  'University Oregon',
#  'Google & University of Washington',
#  'University of Waterloo',
#  'TIFT Mumbai',
#  'Manhattan College',
#  'University College London',
#  'University of Roma Tre, Italy',
#  'University of Paderborn',
#  'LUMS, Pakistan',
#  'Consiglio Nazionale delle Ricerche',
#  'UNSW',
#  'Hong Kong Polytechnic University',
#  'University of Rochester',
#  'Inc. / UCLA',
#  'Massachusetts Institute of TechnologyACS Chief Operating Officer',
#  'University of Illinois Chicago',
#  'Microsoft Research - Inria Joint Centre',
#  'Nyansa Inc.',
#  'Princeton University',
#  'BBN',
#  'IISc Bangalore',
#  'Binghamton University',
#  'National Chiao Tung University',
#  'University of Helsinki',
#  'Oregon State University',
#  'Boston University',
#  'Hungary and Unicamp',
#  'Intel Research',
#  'University of North Carolina at Charlotte',
#  'Upitt',
#  'College Park',
#  'AT&T Labs-Research',
#  'Davis',
#  'Clemson Univ and Stow research',
#  'Oculus',
#  'University of Kiel',
#  'Turin Networks and CMU',
#  'Uppsala University',
#  'University of North Carolina',
#  'USC/Information Sciences Institute (US)',
#  'MPI-SWS',
#  'Shanghai Jiao Tong University',
#  'NIIT University',
#  'Columbia',
#  'University of Rome',
#  'University of Memphis',
#  'University Sydney',
#  'Johns Hopkins University',
#  'CAIDA/UCSD San Diego',
#  'IMDEA Networks Institute',
#  'University of Hawaii',
#  'NCTU',
#  'IBM Thomas J. Watson Research Center',
#  'IUPUI',
#  'Academica Sinica',
#  'SUNY at Buffalo',
#  'University of California San Diego ECE',
#  'Lancaster University',
#  'Graz University of Technology',
#  'Rutgers University',
#  'Lumigent',
#  'Bogazici University',
#  'University of Kentucky',
#  'Caltech',
#  'University of South Carolina',
#  'ICIR',
#  'MPI for Software Systems',
#  'Facebook',
#  'University of Rhode Island',
#  'ABB Corporate Research',
#  'TeraOptic Networks',
#  'DOCOMO Innovations',
#  'SICS / Politecnico di Milano',
#  'University of Wisconsin Madison',
#  'University of Lubeck',
#  'San Diego Research Center',
#  'NSF and University of Pittsburgh',
#  'Jiao Tong University',
#  'IBM T. J. Watson Research Center',
#  'CIPO',
#  'Cisco Meraki',
#  'Madrid Institute for Advanced Studies in Networks (IMDEA Networks)',
#  'University of Massachusett Amherst',
#  'Yokohama National University',
#  'Maynooth University',
#  'Macao Polytechnic Institute',
#  'Northern Arizona University',
#  'HP Laboratories',
#  'University of Michigan Dearborn',
#  'Harvard',
#  'Aalto University',
#  'Paris 11 University',
#  'California State University',
#  'SUNY at Buffalo, USA',
#  'Colorado School of Mines',
#  'University of Adelaide',
#  'University of California Riverside',
#  'BBN Technology',
#  'CreateNet',
#  'Memphis',
#  'Technical University of Dortmund',
#  'Sharp Labs',
#  'University of Illinois Urbana Champaign/Massachusetts Institute of Technology',
#  'DoCoMo Eurolabs',
#  'IBM T.J. Watson Research Center',
#  'University of Massachusetts at Amherst',
#  'Copenhagen',
#  'University of Maryland Baltimore',
#  'Universita di Pisa',
#  'IEEE',
#  'University of Illinois Urbana Champaign',
#  'University of Napoli',
#  'Cisco',
#  'University of Murcia',
#  'Athens University of Economics and Business',
#  'National University of Computer and Emerging Sciences, Pakistan',
#  'NRL',
#  'CNRS and UMPC Sorbonne Universities',
#  'TU Darmstadt',
#  'Nanyang Technological University',
#  'UMass Amherst',
#  'University of Arizona',
#  'McGill',
#  'Google Brain',
#  'Deep Field Networks',
#  'University of Roma Tor Vergata',
#  'University of Oulu',
#  'KTH Royal Institute of Technology',
#  'Intel Research/Carnegie Mellon University',
#  'Reykjavik University',
#  'Korea Electronics Technology Institute',
#  'University of Naples',
#  'Microsoft',
#  'The Hong Kong Polytechnic University',
#  'USTC',
#  'Intel Research Cambridge',
#  'University of California-Berkely',
#  'Group Strategy & Innovation',
#  'EPFL',
#  'University of Szeged, Hungary',
#  'SUNY Stony Brook University',
#  'Paris',
#  'Telcordia Tech.',
#  'Berkeley',
#  'Telefonika',
#  'Alcatel-Lucent Bell Laboratories',
#  'EURECOM',
#  'Toyota InfoTechnology Center',
#  'IBM Zurich',
#  'Amazon',
#  'Washington University',
#  'University of California Davis',
#  'TU Graz / CSH Vienna',
#  'University of Massachusetts-Amherst',
#  'University of California San\xa0Diego',
#  'Stow Research',
#  'Juniper Networks',
#  'Shanghai Jiangtong University',
#  'Michigan State University, USA',
#  'SUPSI',
#  'RWTH Aachen',
#  'NICTA',
#  'Keio University',
#  'Chulalongkorn U.',
#  'University Texas at Arlington',
#  'INRIA Lille-Nord Europe',
#  'Korean Advanced Institute of Science and Technology',
#  'Nest Labs',
#  'University of Virgnia',
#  'SUNY Buffalo',
#  'University of Colorado Boulder & UC Denver',
#  'HP labs',
#  'T-Labs',
#  'Yonsei University',
#  'Intel Labs Settle',
#  'Eurecom',
#  'Netflix',
#  'Pisa, Italy',
#  'National University of Singapore',
#  'Microsoft Research Asia',
#  'Tsinghua University and Tsinghua-Berkeley Shenzhen Institute',
#  'Bell-labs',
#  'INRIA-ENS',
#  'Pennsylvania State University',
#  'University of Texas Austin',
#  'Technische University Berlin',
#  'London',
#  'Stow Research/Clemson University',
#  'University of California Santa Barbara',
#  'University of California Los\xa0Angeles',
#  'Shizuoka University',
#  'U. Karlsruhe',
#  'IMDEA Networks',
#  'Supelec',
#  'Carleton University',
#  'University of Ottawa',
#  'Macquarie University',
#  'Samsung’s Software R&D Center',
#  'OGI School of Engineering',
#  'Cornell Universiity',
#  'Broadcom',
#  'PA',
#  'Nile University',
#  'Lincoln',
#  'BUPT',
#  'TU Dresden',
#  'IBM',
#  'IllinoisInstitute of Technology',
#  'Intel / University of Washington',
#  'Egypt- Japan University of Science and Technology',
#  'INRIA Saclay - Ile-de-France',
#  'UFMG, Brazil',
#  'University of Wurzburg',
#  'IMEC Belgium',
#  'Airdefense',
#  'Universita di Roma Tor Vergata',
#  'Intel Research Pittsburgh',
#  'University of Porto',
#  'Bell Labs Alcatel-Lucent & TU Eindhoven',
#  'US Sprint',
#  'Intel Cambridge Research Lab',
#  'HUJI',
#  'NetApp',
#  'University Paris',
#  'University of Massachusetts - Amherst',
#  'Clemson University and Stow Research L.L.C.',
#  'ATT Labs Research',
#  'SUNYIT',
#  'Albert-Ludwigs-Universität',
#  'Vienna Univ. of Technology, Austria',
#  'Hewlett Packard Labs',
#  'SUNY',
#  'Sprint Advanced Technology Labs',
#  'Intel Labs Berkeley',
#  'University of Tennessee',
#  'Reykjavik University, Iceland',
#  'Penn State University',
#  'Baltimore County',
#  'WUSTL',
#  'Massachusetts Institute of Technology and Georgia Tech',
#  'Politecnico di Milano, Italy and SICS Swedish ICT',
#  'Technische Universität Berlin',
#  'Morgan Stanley',
#  'Columbia University Do Young Eun',
#  'Tohoku University',
#  'Stony Brook',
#  'University Western Australia',
#  'EPFL and University of California in Berkeley',
#  'MSR',
#  'Washington University in St. Louis',
#  'TCS Research & Innovation',
#  'NetLab-SUPSI',
#  'Budapest University of Technology and Economics',
#  'TU Berlin, Germany',
#  'Qualcomm',
#  'City University of Hong Kong',
#  'University Pennsylvania',
#  'IBM Daksh',
#  'IMT',
#  'RISE SICS',
#  'University of Virginia, USA',
#  'University of Brescia',
#  'Hong Kong Univ. of Science and Technology',
#  'Univeristy of Texas Austin',
#  'Singapore University of Technology and Design',
#  'University of Graz',
#  'UT',
#  'IIJ Research Laboratory',
#  'Princeton University and University College London',
#  'VMWare',
#  'University of Innsbruck',
#  'Google/University of California San Diego',
#  'National Polytechnic University',
#  'Fraunhofer IZM',
#  'Vanderbilt University ',
#  'Soroco',
#  'University of New South Wales and CSIRO',
#  'Cleveland State University',
#  'École Polytechnique de Montréal',
#  'University of Athens',
#  'University ofIllinois at Urbana-Champaign',
#  'Las Vegas',
#  'Indiana University',
#  'Create-Net',
#  'Nokia Brazil',
#  'Haier',
#  'Purdue',
#  'University of Szeged',
#  'Luleå University of Technology',
#  'NSFC',
#  'Technion',
#  'Microsoft Research, USA',
#  'IBM Watson Lab',
#  'Indian Institute of Technology in Kanpur India',
#  'MSU and ARCCN',
#  'Air Force Institute of Technology',
#  'University of Tokyo',
#  'Sprint ATL',
#  'Duke and Akamai',
#  'GWU',
#  'University of Souther California / Information Sciences Institute',
#  'Microsoft Research Cambridge',
#  'Florida Atlantic University',
#  'Lancaster University (UK) and University of Arizona (US)',
#  'Seoul National University',
#  'University of Southampton',
#  'University Pierre et Marie Curie',
#  'University of London',
#  'WPI',
#  'University of San Diego',
#  'California Institute of Technology / ETH - Zurich',
#  'Intel Labs',
#  'University of Stuttgart',
#  'University of Science and Technology of China',
#  'University of Michigan/University of Virginia',
#  'Sweden and Politecnico di Milano',
#  'University of Penn.',
#  'University of New South Wales and NICTA',
#  'Wisconsin',
#  'Bell Labs',
#  'University of Iowa',
#  'University of Nebraska-Lincoln',
#  'SICS',
#  'SUNY at Stony Brook',
#  'Palo Alto Research Center',
#  'University of Nebraska',
#  'University of Surrey',
#  'The Ohio State University',
#  'MSR Cambridge',
#  'Hewlett-Packard Laboratories',
#  'Tyndall Institute',
#  'University of Edinburgh',
#  'Army Research Lab',
#  'US Naval Research Laboratory',
#  'Telecom ParisTech',
#  'Yale University',
#  'LinkedIn',
#  'Italy',
#  'Duke University',
#  'ICT CAS',
#  'University Colorado',
#  'CAIDA',
#  'Universitat Politècnica de Catalunya',
#  'National Tsing Hua University',
#  'Chulalongkorn University',
#  'tardo',
#  'Università di Ferrara',
#  'University Pierre & Marie Curie',
#  'ETH Zurich & University of Bologna',
#  'UCSD',
#  'SWITCH',
#  'University of Lancaster',
#  'Microsoft Research Redmond',
#  'NTT Docomo Labs',
#  'Sandia National Labs',
#  'Chung-Ang University',
#  'SICS, Sweden',
#  'Korea UMD',
#  'University of Arkansas',
#  'University of Texas Arlington',
#  'University of Michigan Ann Arbor',
#  'Gatech',
#  'Politecnico di Milan and RISE SICS',
#  'Meru Networks',
#  'University of Texas Dallas',
#  'Schiller',
#  'Hitachi Research, Tokyo',
#  'Stonybrook',
#  'Northwestern',
#  'Lund',
#  'Ericsson Research',
#  'CA',
#  'Styra',
#  'KTH, Sweden',
#  'NASA/BBN',
#  'University College Cork, Ireland',
#  'University of California at Los Angeles',
#  'University of Lyon',
#  'Tyndall Institute, Ireland',
#  'Commonwealth Scientific and Industrial Research Organisation',
#  'Washington State University',
#  'Northeastern University',
#  'ReefEdge',
#  'University of South Carolina Beaufort',
#  'Sabanci University',
#  'UMich',
#  'AT&T Labs -- Research',
#  'University of Technology Sydney',
#  'Bombay',
#  'KTH, Royal Institute of Technology',
#  'JPEO JTRS',
#  'Germany',
#  'MIT Lincoln Lab',
#  'Carnegie Mellon University',
#  'New Hampshire',
#  'University of Lubeck and ETH Zurich',
#  'University of San Francisco',
#  'ISI/USC',
#  'Sapienza',
#  'NUIM',
#  'Università di Milano',
#  'A16Z',
#  'Samsung US',
#  'Deutsche Telekom Labs & TU Berlin',
#  'TU',
#  'IMEC',
#  'Ben Gurion University',
#  'KAIST, Korea',
#  'NSF and University of Pittsburgh (US)',
#  'Boeing',
#  'University Minnesota',
#  'Northwestern University',
#  'University of Cambridge',
#  'University of California',
#  'Chiasserini Polytechnic of Turin',
#  'University Texas',
#  'University of Cincinnati',
#  'Loughborough University',
#  'University of California Berkeley',
#  'University of California Los Angeles',
#  'Indian Institute of Technology',
#  'Wayne State University',
#  'University of Duisburg Essen',
#  'Istanbul Technical University',
#  'Texas A&M University',
#  'Meraki',
#  'NUI Maynooth',
#  'Microsoft Corporation',
#  'Swiss Federal Institute of Technology',
#  'University of Goettingen',
#  'UC Santa Barbara',
#  'Institute of Computing Technology, Chinese Academy of Sciences',
#  'Academic Sinica',
#  'Advanced Digital Sciences Center',
#  'Cambridge',
#  'University of Ferrara',
#  'Penn State',
#  'Hong Kong UST',
#  'University of ssaly',
#  'CERTH',
#  'FBK',
#  'Boston University and Network Appliance',
#  'Madison',
#  'Kiyon Inc.',
#  'TU Delft',
#  'Inria, France',
#  'Portland State',
#  'Hitachi',
#  'Indian Institute of Information Technology (IIIT)',
#  'Rutgers University, USA',
#  'IBM China Research Labs',
#  'Microsoft Research India',
#  'National University of\xa0Mexico',
#  'Riverbed Technology',
#  'Stow Research LLC',
#  'New York University',
#  'Booz Allen Hamilton',
#  'University of Virginia',
#  'UWaterloo',
#  'Google and University of Washington',
#  'Sound Life Sciences',
#  'Tata Institute of Fundamental Research',
#  'Purdue University',
#  'Virginia',
#  'University of Oxford and Samsung AI',
#  'Duke Univeristy / Akamai Technologies',
#  'Vanderbilt University',
#  'University of California Merced',
#  'MPI-SWS/Google',
#  'CityU',
#  'Brocade',
#  'Caltech/IIT Madras',
#  'Università della Svizzera italiana',
#  'IIT-Madras',
#  'DARPA',
#  'SUNY Stonybrook',
#  'HP Laboratories (US)',
#  'University of Wisconsin at Madison',
#  'College of Williamand Mary',
#  'NSF',
#  'Shanghai JiaoTong',
#  'Duke University and Akamai Technologies',
#  'Telefonica',
#  'Grenoble INP-Ensimag',
#  'Thomson',
#  'University of Innsbruck, Austria',
#  'Queensland University of Technology',
#  'Imperial College London',
#  'Microsoft Research, China',
#  'Intentionet',
#  'Michigan',
#  'Barefoot',
#  'Redback Networks',
#  'Stow Research and Clemson Univ.',
#  'IIIT-Delhi',
#  'CUNY',
#  'University at Albany',
#  'University of Crete and FORTH',
#  'National Technical U of Athens',
#  'University of Oxford and Nokia Bell Labs',
#  'University ofMichigan',
#  'University of Birmingham',
#  'Ben-Gurion University of the Negev',
#  'University College London and Nokia Bell Labs',
#  'Fujitsu Laboratories of America',
#  'Ajou University',
#  "King's College London",
#  "Laboratoire d'Informatique de Paris 6",
#  'Santa Cruz',
#  'Facebook Inc.',
#  'University of Dortmund',
#  'AT&T Labs - Research',
#  'Universit "La Sapienza"',
#  'Technicolor',
#  'IIT Kharagpur',
#  'State University of New York at Buffalo',
#  'Niksun',
#  'University of Texas at Dallas, USA',
#  'West Chester University',
#  'Redmond',
#  'Universidad de Valencia',
#  'GM Research',
#  'Nicira Networks',
#  'USC/UCSD',
#  'Stanford',
#  'University of Massachusetts',
#  'UCLA',
#  'NBT Technologies',
#  'Mumbai',
#  'ICT CAS, China',
#  'ICSI',
#  'Salerno',
#  'Duke/Akamai',
#  'Army Research Laboratories',
#  'AT&T',
#  'Shanghai Jiaotong University',
#  'KAUST',
#  'TU Braunschweig',
#  'Università di Roma "La Sapienza"',
#  'IMDEA',
#  'Los Angeles',
#  'Lockheed Martin Advanced Technology Center',
#  'Intel Corporation',
#  'Lausanne',
#  'University of California Davis and SynapSense',
#  'Rice/Technion',
#  'KETI',
#  'University of Sydney',
#  'UTwente',
#  'Telcordia Inc.',
#  'CSIRO',
#  'Rensselaer Polytechnic Institute',
#  'Deutsche Telekom Laboratories',
#  'Qualcomm Inc.',
#  'Università di Pisa',
#  'National and Kapodistrian University of Athens',
#  'ISI',
#  'IBM India Research Lab',
#  'National Chiao-Tung University',
#  'Intel Research Berkeley',
#  'UPB',
#  "Universita' degli Studi di Roma",
#  'CNR - IIT',
#  'HongKong City University',
#  'Clemson University and Stow Research L.L.C',
#  'Hamilton Institute',
#  'University of Chinese Academy of Science',
#  'Carnegie Mellon',
#  'University of Wisconsin',
#  'NTT Docomolabs',
#  'TU Eindhoven',
#  'NIKSUN',
#  'Google',
#  'University of Canterbury, New Zealand',
#  'McGill University',
#  'University of Palermo',
#  'Bell Labs India',
#  'Sapienza University of Rome',
#  'Rome University',
#  'Iowa State University',
#  'Atos',
#  'Universidad Carlos III de Madrid',
#  'Nanyang Technical University',
#  'Microsoft - England',
#  'HPE',
#  'UT Austin',
#  'Technion – Israel Institute of Technology',
#  'Korean University',
#  'University of Pittsburgh',
#  'Uber Inc.',
#  'UCSC',
#  'Raytheon BBN Technologies',
#  'Deutsche Telekom Labs/TU-Berlin',
#  'Arbor Networks',
#  'Colorado State University',
#  'University of Melbourne',
#  'Technical University of Berlin',
#  'UW',
#  ...]

# %%
set(uni_df['California Institute of Technology']['Name'])
# Out:
# {'Jayakrishnan Nair', 'Jayakrishnan Unnikrishnan Nair', 'Steven Low'}
